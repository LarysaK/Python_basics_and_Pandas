# %% [markdown]
# <a href="https://colab.research.google.com/github/LarysaK/Python_basics_and_Pandas/blob/main/Python_basics_and_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Exercise 1: Data Analysis and Manipulation with Pandas
# In this exercise, we will be working with two datasets: sales data and customer data. We will use pandas to perform various data analysis and manipulation tasks.

# %% [markdown]
# ### Part 1: Loading Data
# 1. Load the sales data using pandas read_csv function and assign it to a variable called sales_data.
# 2. Load the customer data using pandas read_csv function and assign it to a variable called customer_data.
#
# **Note: Both CSV files are located in the same directory as this Jupyter notebook.**

# %%
import pandas as pd
sales_data = pd.read_csv('sales_data.csv')   
sales_data
# Out:
#     Unnamed: 0        date product salesperson  units_sold  sales_amount
# 0            0  2022-01-01       B         Bob           7            27
# 1            1  2022-01-02       A       Alice           1            41
# 2            2  2022-01-03       B       Alice           8            33
# 3            3  2022-01-04       C     Charlie           6            80
# 4            4  2022-01-05       B         Bob           2            38
# 5            5  2022-01-06       A         Bob           9            93
# 6            6  2022-01-07       A     Charlie           3            32
# 7            7  2022-01-08       C       Alice           4            32
# 8            8  2022-01-09       B         Bob           9            20
# 9            9  2022-01-10       B         Bob           5            63
# 10          10  2022-01-11       C     Charlie           6            69
# 11          11  2022-01-12       A     Charlie           1            82
# 12          12  2022-01-13       B         Bob           3            99
# 13          13  2022-01-14       A     Charlie           8            99
# 14          14  2022-01-15       B     Charlie           4            72
# 15          15  2022-01-16       A     Charlie           8            70
# 16          16  2022-01-17       A       Alice           4            96
# 17          17  2022-01-18       C         Bob           4            98
# 18          18  2022-01-19       B       Alice           4            92
# 19          19  2022-01-20       B     Charlie           1            51
# 20          20  2022-01-21       C         Bob           4            65
# 21          21  2022-01-22       B         Bob           9            29
# 22          22  2022-01-23       C     Charlie           6            96
# 23          23  2022-01-24       A     Charlie           5            79
# 24          24  2022-01-25       A       Alice           3            64
# 25          25  2022-01-26       B         Bob           5            88
# 26          26  2022-01-27       B         Bob           2            71
# 27          27  2022-01-28       B     Charlie           7            57
# 28          28  2022-01-29       B         Bob           8            47
# 29          29  2022-01-30       B       Alice           1            41

# %%
import pandas as pd
customer_data = pd.read_csv('customer_data.csv')  
customer_data
# Out:
#    Unnamed: 0      name state salesperson  customer_id
# 0           0   Jeremie    CA       Alice            1
# 1           1  Mathilde    NY         Bob            2
# 2           2    Pierre    TX     Charlie            3

# %% [markdown]
# ### Part 2: Data Exploration
# In this exercise, we will explore the two datasets that we loaded in Part 1.

# %% [markdown]
# - Check the shape of both dataframes. How many rows and columns do they have?

# %%
print(sales_data.shape, customer_data.shape)
# Out:
# (30, 6) (3, 5)

# %% [markdown]
# - Print the first 5 rows of both datasets.

# %%
sales_data.head(5)
# Out:
#    Unnamed: 0        date product salesperson  units_sold  sales_amount
# 0           0  2022-01-01       B         Bob           7            27
# 1           1  2022-01-02       A       Alice           1            41
# 2           2  2022-01-03       B       Alice           8            33
# 3           3  2022-01-04       C     Charlie           6            80
# 4           4  2022-01-05       B         Bob           2            38

# %%
customer_data.head(5)
# Out:
#    Unnamed: 0      name state salesperson  customer_id
# 0           0   Jeremie    CA       Alice            1
# 1           1  Mathilde    NY         Bob            2
# 2           2    Pierre    TX     Charlie            3

# %% [markdown]
# - Use the describe method to generate basic summary statistics for the sales_data DataFrame.

# %%
sales_data_stats = sales_data.describe()
sales_data_stats
# Out:
#        Unnamed: 0  units_sold  sales_amount
# count   30.000000   30.000000     30.000000
# mean    14.500000    4.900000     64.133333
# std      8.803408    2.591099     25.335995
# min      0.000000    1.000000     20.000000
# 25%      7.250000    3.000000     41.000000
# 50%     14.500000    4.500000     67.000000
# 75%     21.750000    7.000000     86.500000
# max     29.000000    9.000000     99.000000

# %% [markdown]
# - Use the groupby method to calculate the total sales amount and total units sold for each salesperson in the sales_data DataFrame.

# %%
salesperson_stats = sales_data.groupby('salesperson').agg({'sales_amount': 'sum', 'units_sold': 'sum'})
salesperson_stats
# Out:
#              sales_amount  units_sold
# salesperson
# Alice                 399          25
# Bob                   738          67
# Charlie               787          55

# %% [markdown]
# - Use the groupby method to calculate the total sales amount and total units sold for each product in the sales_data DataFrame.

# %%
product_stats = sales_data.groupby('product').agg({'sales_amount': 'sum', 'units_sold': 'sum'})
product_stats
# Out:
#          sales_amount  units_sold
# product
# A                 656          42
# B                 828          75
# C                 440          30

# %% [markdown]
# - Use the merge method to merge the sales_data and customer_data DataFrames on the salesperson column. How many rows and columns does the resulting DataFrame have?

# %%
merge_data = sales_data.merge(customer_data, on='salesperson')
merge_data
#merge_data.shape
# Out:
#     Unnamed: 0_x        date product salesperson  units_sold  sales_amount  \
# 0              0  2022-01-01       B         Bob           7            27
# 1              4  2022-01-05       B         Bob           2            38
# 2              5  2022-01-06       A         Bob           9            93
# 3              8  2022-01-09       B         Bob           9            20
# 4              9  2022-01-10       B         Bob           5            63
# 5             12  2022-01-13       B         Bob           3            99
# 6             17  2022-01-18       C         Bob           4            98
# 7             20  2022-01-21       C         Bob           4            65
# 8             21  2022-01-22       B         Bob           9            29
# 9             25  2022-01-26       B         Bob           5            88
# 10            26  2022-01-27       B         Bob           2            71
# 11            28  2022-01-29       B         Bob           8            47
# 12             1  2022-01-02       A       Alice           1            41
# 13             2  2022-01-03       B       Alice           8            33
# 14             7  2022-01-08       C       Alice           4            32
# 15            16  2022-01-17       A       Alice           4            96
# 16            18  2022-01-19       B       Alice           4            92
# 17            24  2022-01-25       A       Alice           3            64
# 18            29  2022-01-30       B       Alice           1            41
# 19             3  2022-01-04       C     Charlie           6            80
# 20             6  2022-01-07       A     Charlie           3            32
# 21            10  2022-01-11       C     Charlie           6            69
# 22            11  2022-01-12       A     Charlie           1            82
# 23            13  2022-01-14       A     Charlie           8            99
# 24            14  2022-01-15       B     Charlie           4            72
# 25            15  2022-01-16       A     Charlie           8            70
# 26            19  2022-01-20       B     Charlie           1            51
# 27            22  2022-01-23       C     Charlie           6            96
# 28            23  2022-01-24       A     Charlie           5            79
# 29            27  2022-01-28       B     Charlie           7            57
#
#     Unnamed: 0_y      name state  customer_id
# 0              1  Mathilde    NY            2
# 1              1  Mathilde    NY            2
# 2              1  Mathilde    NY            2
# 3              1  Mathilde    NY            2
# 4              1  Mathilde    NY            2
# 5              1  Mathilde    NY            2
# 6              1  Mathilde    NY            2
# 7              1  Mathilde    NY            2
# 8              1  Mathilde    NY            2
# 9              1  Mathilde    NY            2
# 10             1  Mathilde    NY            2
# 11             1  Mathilde    NY            2
# 12             0   Jeremie    CA            1
# 13             0   Jeremie    CA            1
# 14             0   Jeremie    CA            1
# 15             0   Jeremie    CA            1
# 16             0   Jeremie    CA            1
# 17             0   Jeremie    CA            1
# 18             0   Jeremie    CA            1
# 19             2    Pierre    TX            3
# 20             2    Pierre    TX            3
# 21             2    Pierre    TX            3
# 22             2    Pierre    TX            3
# 23             2    Pierre    TX            3
# 24             2    Pierre    TX            3
# 25             2    Pierre    TX            3
# 26             2    Pierre    TX            3
# 27             2    Pierre    TX            3
# 28             2    Pierre    TX            3
# 29             2    Pierre    TX            3

# %% [markdown]
# - Use the groupby method to calculate the total sales amount and total units sold for each customer in the merged DataFrame.

# %%
customer_stats = merge_data.groupby('customer_id').agg({'sales_amount': 'sum', 'units_sold': 'sum'})
customer_stats
# Out:
#              sales_amount  units_sold
# customer_id
# 1                     399          25
# 2                     738          67
# 3                     787          55

# %% [markdown]
# ### Part 3: Data Cleaning
# In this exercise, we will clean the sales_data dataframe.

# %% [markdown]
# - Identify any missing values in the sales_data DataFrame. If there are any, fill them in with appropriate values.

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    30 non-null     int64
#  1   date          30 non-null     object
#  2   product       30 non-null     object
#  3   salesperson   30 non-null     object
#  4   units_sold    30 non-null     int64
#  5   sales_amount  30 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.5+ KB

# %% [markdown]
# - Identify and remove any duplicates in the sales_data DataFrame.

# %%
# Identify duplicates
duplicate_rows = sales_data.duplicated()
duplicate_rows.sum()


# Remove duplicates
#sales_data_unique = sales_data.drop_duplicates()
# Out:
# 0

# %% [markdown]
# - Identify any missing values in the customer_data DataFrame. If there are any, fill them in with appropriate values.

# %%
 customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   3 non-null      int64
#  1   name         3 non-null      object
#  2   state        3 non-null      object
#  3   salesperson  3 non-null      object
#  4   customer_id  3 non-null      int64
# dtypes: int64(2), object(3)
# memory usage: 248.0+ bytes

# %% [markdown]
# - Identify and remove any duplicates in the customer_data DataFrame.

# %%
duplicates_rows = customer_data.duplicated()
duplicates_rows.sum()
# Out:
# 0

# %% [markdown]
# ### Part 4: Data Transformation

# %% [markdown]
# - Create a new column in the sales_data DataFrame called total_sales that is the product of the units_sold and sales_amount columns.

# %%
sales_data['total_sales'] = sales_data['units_sold'] * sales_data['sales_amount']
sales_data
# Out:
#     Unnamed: 0        date product salesperson  units_sold  sales_amount  \
# 0            0  2022-01-01       B         Bob           7            27
# 1            1  2022-01-02       A       Alice           1            41
# 2            2  2022-01-03       B       Alice           8            33
# 3            3  2022-01-04       C     Charlie           6            80
# 4            4  2022-01-05       B         Bob           2            38
# 5            5  2022-01-06       A         Bob           9            93
# 6            6  2022-01-07       A     Charlie           3            32
# 7            7  2022-01-08       C       Alice           4            32
# 8            8  2022-01-09       B         Bob           9            20
# 9            9  2022-01-10       B         Bob           5            63
# 10          10  2022-01-11       C     Charlie           6            69
# 11          11  2022-01-12       A     Charlie           1            82
# 12          12  2022-01-13       B         Bob           3            99
# 13          13  2022-01-14       A     Charlie           8            99
# 14          14  2022-01-15       B     Charlie           4            72
# 15          15  2022-01-16       A     Charlie           8            70
# 16          16  2022-01-17       A       Alice           4            96
# 17          17  2022-01-18       C         Bob           4            98
# 18          18  2022-01-19       B       Alice           4            92
# 19          19  2022-01-20       B     Charlie           1            51
# 20          20  2022-01-21       C         Bob           4            65
# 21          21  2022-01-22       B         Bob           9            29
# 22          22  2022-01-23       C     Charlie           6            96
# 23          23  2022-01-24       A     Charlie           5            79
# 24          24  2022-01-25       A       Alice           3            64
# 25          25  2022-01-26       B         Bob           5            88
# 26          26  2022-01-27       B         Bob           2            71
# 27          27  2022-01-28       B     Charlie           7            57
# 28          28  2022-01-29       B         Bob           8            47
# 29          29  2022-01-30       B       Alice           1            41
#
#     total_sales
# 0           189
# 1            41
# 2           264
# 3           480
# 4            76
# 5           837
# 6            96
# 7           128
# 8           180
# 9           315
# 10          414
# 11           82
# 12          297
# 13          792
# 14          288
# 15          560
# 16          384
# 17          392
# 18          368
# 19           51
# 20          260
# 21          261
# 22          576
# 23          395
# 24          192
# 25          440
# 26          142
# 27          399
# 28          376
# 29           41

# %% [markdown]
# - Create a new column in the sales_data DataFrame called year that is the year of the date column.

# %%
sales_data['year'] = pd.to_datetime(sales_data['date']).dt.year
sales_data
# Out:
#     Unnamed: 0        date product salesperson  units_sold  sales_amount  \
# 0            0  2022-01-01       B         Bob           7            27
# 1            1  2022-01-02       A       Alice           1            41
# 2            2  2022-01-03       B       Alice           8            33
# 3            3  2022-01-04       C     Charlie           6            80
# 4            4  2022-01-05       B         Bob           2            38
# 5            5  2022-01-06       A         Bob           9            93
# 6            6  2022-01-07       A     Charlie           3            32
# 7            7  2022-01-08       C       Alice           4            32
# 8            8  2022-01-09       B         Bob           9            20
# 9            9  2022-01-10       B         Bob           5            63
# 10          10  2022-01-11       C     Charlie           6            69
# 11          11  2022-01-12       A     Charlie           1            82
# 12          12  2022-01-13       B         Bob           3            99
# 13          13  2022-01-14       A     Charlie           8            99
# 14          14  2022-01-15       B     Charlie           4            72
# 15          15  2022-01-16       A     Charlie           8            70
# 16          16  2022-01-17       A       Alice           4            96
# 17          17  2022-01-18       C         Bob           4            98
# 18          18  2022-01-19       B       Alice           4            92
# 19          19  2022-01-20       B     Charlie           1            51
# 20          20  2022-01-21       C         Bob           4            65
# 21          21  2022-01-22       B         Bob           9            29
# 22          22  2022-01-23       C     Charlie           6            96
# 23          23  2022-01-24       A     Charlie           5            79
# 24          24  2022-01-25       A       Alice           3            64
# 25          25  2022-01-26       B         Bob           5            88
# 26          26  2022-01-27       B         Bob           2            71
# 27          27  2022-01-28       B     Charlie           7            57
# 28          28  2022-01-29       B         Bob           8            47
# 29          29  2022-01-30       B       Alice           1            41
#
#     total_sales  year
# 0           189  2022
# 1            41  2022
# 2           264  2022
# 3           480  2022
# 4            76  2022
# 5           837  2022
# 6            96  2022
# 7           128  2022
# 8           180  2022
# 9           315  2022
# 10          414  2022
# 11           82  2022
# 12          297  2022
# 13          792  2022
# 14          288  2022
# 15          560  2022
# 16          384  2022
# 17          392  2022
# 18          368  2022
# 19           51  2022
# 20          260  2022
# 21          261  2022
# 22          576  2022
# 23          395  2022
# 24          192  2022
# 25          440  2022
# 26          142  2022
# 27          399  2022
# 28          376  2022
# 29           41  2022

# %% [markdown]
# - Create a new DataFrame called sales_by_state that shows the total sales amount and total units sold for each state in the customer_data DataFrame.

# %%
 sales_by_state = merge_data.groupby('state').agg({'sales_amount': 'sum', 'units_sold': 'sum'}).reset_index()
 sales_by_state
# Out:
#   state  sales_amount  units_sold
# 0    CA           399          25
# 1    NY           738          67
# 2    TX           787          55

# %% [markdown]
# - Create a new DataFrame called sales_by_month that shows the total sales amount and total units sold for each month in the sales_data DataFrame.

# %%
sales_data['date'] = pd.to_datetime(sales_data['date'])
sales_by_month = sales_data.groupby(sales_data['date'].dt.month).agg({'sales_amount': 'sum', 'units_sold': 'sum'}).reset_index()
sales_by_month
# Out:
#    date  sales_amount  units_sold
# 0     1          1924         147

# %% [markdown]
# ### Part 5: Data Visualization

# %% [markdown]
# - Use the plot method to create a bar chart showing the total sales amount for each salesperson in the sales_data DataFrame.

# %%
import matplotlib.pyplot as plt

salesperson_stats = sales_data.groupby('salesperson')['sales_amount'].sum()
salesperson_stats.plot(kind='bar')

plt.xlabel('Salesperson')
plt.ylabel('Total Sales Amount')
plt.title('Total Sales Amount by Salesperson')

plt.show()

# %% [markdown]
# - Use the plot method to create a bar chart showing the total sales amount for each product in the sales_data DataFrame.

# %%
product_stats = sales_data.groupby('product')['sales_amount'].sum()
product_stats.plot(kind='bar')

plt.xlabel('Product')
plt.ylabel('Total Sales Amount')
plt.title('Total Sales Amount by Product')

plt.show()

# %% [markdown]
# - Use the plot method to create a bar chart showing the total sales amount for each state in the customer_data DataFrame.

# %%
state_stats = merge_data.groupby('state')['sales_amount'].sum()
state_stats.plot(kind='bar')

plt.xlabel('State')
plt.ylabel('Total Sales Amount')
plt.title('Total Sales Amount by State')

plt.show()
